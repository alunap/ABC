# %%
import plotly.express as px
from OSGridConverter import grid2latlong

# %%
import numpy as np
import pandas as pd

# %%
bird_counts = pd.read_parquet("../data/exp_pro/bird_counts.parquet")

# %%
bird_counts.head()
# Out:
#              Species        Date  DayCount
# 0  Bar-tailed Godwit  1992-09-13         2
# 1         Greenshank  1992-09-13         2
# 2             Curlew  1992-09-13        33
# 3           Redshank  1992-09-13         6
# 4               Teal  1992-09-13         4

# %%
birds = pd.read_parquet("../data/exp_pro/birds.parquet")
